# %%
# get optimal parameters from TT - UNDERSTAND WHY AND WRITE IT??

# %%
# can experiment what params make DSA fail at ignoring nonlinearities
# so it identifies exactly the same model as different just because of a nonlinear mapping
